# %%
import json
import numpy as np

# %%
tweet_json_file = "./data/all_tweets_with_coding.json"
with open(tweet_json_file, 'r') as f:
    tweets = json.load(f)

# %%
num_samples = 500
attack_samples = 500

attack_tweets = [tweet for tweet in tweets if tweet["is_attack"]]

np.random.seed(42)

random_total_sample = np.random.choice(tweets, num_samples)
random_attack_sample = np.random.choice(attack_tweets, num_samples)

# %%
for sample in random_sample:
    print(sample["text"])
    print("is_attack", sample["is_attack"])
    print("is_policy", sample["is_policy"])
    print("is_contrast", sample["is_contrast"])
    print()
# Out:
# .@TomPreciousALB: Astorino will folo Cuomo's bus with "Shelly Silver Express" MT HH will lead both in Syr with human powered pedicab
# is_attack True
# is_policy False
# is_contrast False
#
# Nevada Governor 2014 Debate VanDerBeek v. Goodman Education http://t.co/SKItsEyXkz
# is_attack True
# is_policy True
# is_contrast False
#
# .@WolfForPA thinks PA families don’t pay enough taxes so he wants to triple their personal income tax rate. http://t.co/rXstFLWQBh #pagov
# is_attack False
# is_policy False
# is_contrast False
#
# Incredible tour of the Indian River with @MarkPafford. We'll do everything we can to restore this natural treasure. http://t.co/Bgiferprfi
# is_attack False
# is_policy False
# is_contrast False
#
# @TddDnnsn Thanks for the notification!
# is_attack False
# is_policy False
# is_contrast False
#
# We'll kick off our Live and Uncensored blitz tomorrow at 6:00 pm at the Park Co. Library. #AnyQuestion #AnyTime
# is_attack False
# is_policy False
# is_contrast False
#
# @cannabisstrains Libertarians are trying to free the weed. #InvisibleCandidates http://t.co/OsFzvvbdMF
# is_attack False
# is_policy False
# is_contrast False
#
# Thanks to @GovBrewer for joining Team Ducey for ice cream this afternoon! #azgov http://t.co/vOyeAOpRwi
# is_attack False
# is_policy False
# is_contrast False
#
# “@bluecheddar1: Good Morning.” Good morning to you too.
# is_attack False
# is_policy False
# is_contrast False
#
# #FLGovDebate will air in every city in Florida as well as online. Find out where to watch! http://t.co/6raQrcdUaq http://t.co/W70rCrbinK
# is_attack False
# is_policy False
# is_contrast False
#
# This Saturday's rally is going to be incredible. I really hope you can make it.
#
# http://t.co/DPEknBMArv http://t.co/KkbHtxPCA9
# is_attack False
# is_policy False
# is_contrast False
#
# Thanks Jenn! RT @JefferMed as a major Martha Coakley fan, seeing @emilyslist mentioned in her 1st ad made my day! https://t.co/cn7yEL3Dwr
# is_attack False
# is_policy False
# is_contrast False
#
# Underway now: Updating New Yorkers on #Ebola preparedness steps in New York State http://t.co/i1cZKtHYS1
# is_attack False
# is_policy False
# is_contrast False
#
# The best explanation of this election by Clayton Bell!
#
# Clayton Bell: "A vote not cast is the wasted vote, just... http://t.co/stD61UUpLD
# is_attack False
# is_policy False
# is_contrast False
#
# On the trail, I mentioned that I'm running for Wisconsin while my opponent is running against me. That's the difference.
# is_attack True
# is_policy False
# is_contrast True
#
# ;@arendabdoory It's comical, the gop operatives are convinced #WyllieForGov throws election TO @CharlieCrist &amp; vice-versa!
# is_attack True
# is_policy False
# is_contrast False
#
# Don't get caught in The Trap! #RestoreLiberty #RestoreColorado #Dunafon4Gov http://t.co/05FBiWu3g7
# is_attack False
# is_policy False
# is_contrast False
#
# .@SheriffMoss and I will crack down on Albany corruption. #ABNY
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you! MT @SEIUTX: #SundayFunday means hitting doors for Wendy Davis &amp; @leticiavdp w/ @TXOrgProject. #TeamWendy http://t.co/600LU8Fshm
# is_attack False
# is_policy False
# is_contrast False
#
# Watch @WolfForPA draw on his biz experience to defend @GovernorCorbett on treasury loan. #pagov https://t.co/z57qDTobeB #pagov
# is_attack False
# is_policy False
# is_contrast False
#
# #Hawkins ad against #Cuomo casino economy, political corruption and tax cuts for the rich. Wake Up NY. http://t.co/TcNxT9VLp6
# is_attack False
# is_policy False
# is_contrast False
#
# We want classrooms that promote wonder, make-believe, humor, joy, genuine inquiry, and fun on all our schools. Please Retweet if you agree!
# is_attack False
# is_policy False
# is_contrast False
#
# Some photos of my last two stops in our #99county tour #IAgov #IAvotes http://t.co/LrDeodlK7L
# is_attack False
# is_policy False
# is_contrast False
#
# Tonight, re-visit the debate, this time with @WyllieForGov included on WHDT http://t.co/Z2tyzZP6nx #nextflgov #FLGovDebate #flgov #sayfie
# is_attack False
# is_policy False
# is_contrast False
#
# Today is the last day to vote early at your town office! #vtpoli #vt
# is_attack False
# is_policy False
# is_contrast False
#
# .@dailykos: What would a 2014 Republican wave look like? Odds are, not like this. http://t.co/OVqiRuMluK
# is_attack False
# is_policy False
# is_contrast False
#
# @Rach_IC @BradHubert @brianjsymes There are only 'libertarians'--no such thing as a conservative, liberal or moderate. 'Leaners' R liars.
# is_attack False
# is_policy False
# is_contrast False
#
# #LetsKeepWorking! Check out Rick Scott’s plan to make Florida the #1 place for job creation in the county! http://t.co/RoqK2NVUgS #sayfie
# is_attack False
# is_policy False
# is_contrast False
#
# Spoke with Michigan Corrections Officers about the need to fully staff our prisons and move Michigan forward. http://t.co/JkDQnGNWXh
# is_attack False
# is_policy False
# is_contrast False
#
# Enjoyed visiting with the @BBnewsroom yesterday during my trip to Mountain Home. Thanks for the time! http://t.co/HwmRrjGkpc #ARGov
# is_attack False
# is_policy False
# is_contrast False
#
# @newsservicefla Tune in Sunday night for a re-visit to the debate, this time with #Wyllie included 6pm on WHDT tv http://t.co/Z2tyzZP6nx
# is_attack False
# is_policy False
# is_contrast False
#
# @gprince1110 You can tweet to the media personalities. There are also groups against All Aboard. They'll want to hear from you.
# is_attack False
# is_policy False
# is_contrast False
#
# Meeting with our troops abroad in Afghanistan. http://t.co/Py2ieEFjnE
# is_attack False
# is_policy False
# is_contrast False
#
# Trying to think of examples besides Watergate when a politician's long career was overshadowed by a horrible decision at the end. #Vergara
# is_attack False
# is_policy False
# is_contrast False
#
# Local Government Local Control #nysgovdebate #empowerny @TheBuffaloNews
# is_attack False
# is_policy False
# is_contrast False
#
# There's been a lot of hateful, false attacks spread about Fred, but we're more committed than ever to moving #AZFWD  http://t.co/8xrUpzMgGe
# is_attack False
# is_policy False
# is_contrast False
#
# Victory depends on you! Come join the team! http://t.co/U8bt1QilaK #letskeepworking http://t.co/AW0hX4D6JB
# is_attack False
# is_policy False
# is_contrast False
#
# “as Dr. Hunt said...” Jason Carter http://t.co/YQlTH6jlAg @LPGeorgia #HuntForGovernor #gagov #gapol #gagop #gadems http://t.co/QuH2TxAFz2
# is_attack True
# is_policy False
# is_contrast False
#
# Thanks to all who came out to the Kasich/Taylor #Buckeyes Home Opener Cookout! Let's beat the Hokies! O-H! http://t.co/REorqG8bvx
# is_attack False
# is_policy False
# is_contrast False
#
# “@BurkeWIGov: “@js_newswatch: Final debate gives…” a bad name to journalism #WIGovDebate”
# is_attack False
# is_policy False
# is_contrast False
#
# Thanking supporters for their energy and enthusiasm at today's parade in Milford. #nhpolitics #nhgov http://t.co/ccJcxcRCR8
# is_attack False
# is_policy False
# is_contrast False
#
# Answer to Heilmann Melody: It would be smart to Vote Khavari!
#
# "Heilmann Melody I may consider voting for... http://t.co/e0w73rRDx1
# is_attack False
# is_policy False
# is_contrast False
#
# Millions of Texans are ready to vote--but we need #lawyers to help make sure they can. Volunteer now: http://t.co/nZpLPI8yVQ
# is_attack False
# is_policy False
# is_contrast False
#
# @Rhino0331 My OK Dept of Commerce will emphasize small business development &amp; partner w/ career techs to assist small business job training
# is_attack False
# is_policy False
# is_contrast False
#
# Wed Aug 11 #Wyllie4Gov #CraftBeer Tour will be in Largo @BarleyMowBrew https://t.co/XWjOaQ4Ral @WFLALauren @PinellasLP @learyreports
# is_attack False
# is_policy False
# is_contrast False
#
# @Runcie thank you!
# is_attack False
# is_policy False
# is_contrast False
#
# AR needs jobs &amp; I have an effective and concrete plan to attract and keep businesses http://t.co/D3umIlmOJT http://t.co/M2O2x0D7Sw
# is_attack False
# is_policy False
# is_contrast False
#
# .@freep: Clinton urges vote against wealthy, special interests http://t.co/eJBpglgND0 http://t.co/ET34uUryzx
# is_attack False
# is_policy False
# is_contrast False
#
# Rutherford plans to bring budget reform if elected with Hogan http://t.co/J7hFuaq3Vc via @thedbk #mdpolitics @mdreps @umdrepublicans
# is_attack False
# is_policy False
# is_contrast False
#
# Good read in @petoskeynews: Northern Michigan has stake in Detroit's well-being -- and vice versa http://t.co/hOun9XQlFa
# is_attack False
# is_policy False
# is_contrast False
#
# Show your support for Joe Dorman on your social media! Download a #TeamDorman profile pictures or cover photo here: https://t.co/xOHgHsAFN8
# is_attack False
# is_policy False
# is_contrast False
#
# We can use your help! Support Democrats by knocking on 50 doors this weekend. http://t.co/4LpbgQS0TC http://t.co/buchCtHaiL
# is_attack False
# is_policy False
# is_contrast False
#
# .@minurses shine light on Gov. Snyder's harmful policies: New TV ad advocates for safe care for all patients http://t.co/Mqb80Ot3BM
# is_attack False
# is_policy False
# is_contrast False
#
# Vote for the education governor–vote for Wendy. http://t.co/0kOZ8TShow -Team Wendy #MyTexasVotes #MiVotoMiVoz #TeamWendy
# is_attack False
# is_policy False
# is_contrast False
#
# It is easy to find a volunteer opportunity near you, just go to http://t.co/eiCU5TXtcQ and enter your zip code! #mapoli #magov
# is_attack False
# is_policy False
# is_contrast False
#
# "This is what my campaign is all about: We need to create an economy that works for everyone, not just the wealthy and well-connected." - MS
# is_attack False
# is_policy False
# is_contrast False
#
# .@NYGovCuomo. Support Our Dreams, Not our Fears. The $2 hr min wage 51 years ago at MLK rally would be $15+ today. http://t.co/IhOJvzX92R
# is_attack True
# is_policy True
# is_contrast True
#
# The 1st Hispanic First Lady of Texas (soon-to-be) is working to Keep Texas Red @HRTexas  http://t.co/uWYsvX7EmT
# is_attack False
# is_policy False
# is_contrast False
#
# Your. Vote. Matters. Vote on Election Day–http://t.co/zL4dmI612w  #MyTexasVotes -Team Wendy
# is_attack False
# is_policy False
# is_contrast False
#
# You know @FLGovScott @CharlieCrist are both part of Florida;s crony corruption, VOTE @WyllieForGov to clean it up http://t.co/jhZMVcqWL4
# is_attack True
# is_policy False
# is_contrast False
#
# Be sure to check out today’s poll from the Star Tribune. In short, victory is within our grasp! http://t.co/oEXgc7HBHE #mngov
# is_attack False
# is_policy False
# is_contrast False
#
# “@NicholsUprising: @BurkeWIGov Here's my piece on Robert Burke and the 2014 Libertarian campaign in Wisconsin.”I'm assuming the blank was...
# is_attack True
# is_policy False
# is_contrast True
#
# @CTLizB Former Mobil VP &amp; #Fractivist Lou Allstadt endorses Hawkins for "unequivocally" opposing #fracking http://t.co/yyBuDjNvsA
# is_attack False
# is_policy False
# is_contrast False
#
# Mark Dayton needs to start taking responsibility for what happens in his administration. MNs deserve better. #MNGov
# is_attack True
# is_policy False
# is_contrast False
#
# My 1st job was washing dishes at the Countryside Restaurant.  In high school, I went on to work at McDonald's to save for college.
# is_attack False
# is_policy False
# is_contrast False
#
# Because Rick Scott failed to expand health care, parents are struggling. Heartbreaking: http://t.co/ni8VSYiRtS http://t.co/sLloruEse4
# is_attack True
# is_policy True
# is_contrast False
#
# Talking about making New York great again with @fud31 on @TALK1300 now. Listen here: talk1300.c0m
# is_attack False
# is_policy False
# is_contrast False
#
# If you were affected by SE Michigan flood, call 800-621-FEMA for financial assistance. Deadline to apply is 11/24
# is_attack False
# is_policy False
# is_contrast False
#
# GREAT NEWS! Edmond Sun has endorsed Mary! Joins The Oklahoman, Tulsa World, Lawton Constitution and other endorsing! http://t.co/APwtFHO460
# is_attack False
# is_policy False
# is_contrast False
#
# In Tucson? Catch my interview w/ @lorrainerivera on @azweek tonight at 9 on @azpmnews! If you're in #PHX catch me at 6:30 on @arizonapbs.
# is_attack False
# is_policy False
# is_contrast False
#
# Vote for her future: http://t.co/5YZguhY3yC http://t.co/VKL0yELsKx
# is_attack False
# is_policy False
# is_contrast False
#
# Congratulations to the honorees at tonight's Blackstone Valley Tourism Council annual dinner http://t.co/ZArI8ZI2Jo
# is_attack False
# is_policy False
# is_contrast False
#
# @DeniseProvost1 which is clearly at least 1%!
# is_attack False
# is_policy False
# is_contrast False
#
# Nice visit to the Franklin County Fair in Greenfield today - stop by our table if you are heading over.
# is_attack False
# is_policy False
# is_contrast False
#
# I had a great time yesterday at the UMOS Mexican Independence Day Parade in Milwaukee! http://t.co/721IWnMm4h
# is_attack False
# is_policy False
# is_contrast False
#
# #TeamWendy, this is your chance to make history. Get out the vote and help all Texans be heard in this election. http://t.co/wvJiSkxWaY
# is_attack False
# is_policy False
# is_contrast False
#
# @roberthaymes33 @Pompanopete @adamputnam @Forbes Lobbyists know to bypass Wyllie, his only 'special interest' is helping the citizens of FL!
# is_attack False
# is_policy False
# is_contrast False
#
# Give $15 so everyone can get $15! Minimum wage for NY should be $15 an hour, and @HowieHawkins know it! https://t.co/GPaRXJiE0k  #15for15
# is_attack False
# is_policy False
# is_contrast False
#
# View the latest ad, here: http://t.co/6WMcHBeO4o
# is_attack False
# is_policy False
# is_contrast False
#
# Filibustering is hard. Registering to vote isn't. Check out 22 things harder than registering to vote in Texas: http://t.co/7UYgQ70VAj
# is_attack False
# is_policy False
# is_contrast False
#
# “@csalmon420: “@SupportRobBurke: Vote Robert Burke, Get Blazed. #MtRushMoreOfWeed
# https://t.co/czJrrE90iD” this is a great ad”  I'm floored
# is_attack True
# is_policy False
# is_contrast False
#
# "Walker in Weston: 'I'm the No. 1 target in America'"
# http://t.co/XmoHGq0TzN
# is_attack False
# is_policy False
# is_contrast False
#
# I'm here in West Texas today to visit the Odessa Crisis Center &amp; talk about my fight for survivors of rape and sexual assault.
# is_attack False
# is_policy False
# is_contrast False
#
# It is time we value our teachers in this great state who are preparing #SouthDakota's next generation. #SDGov http://t.co/O1hQfzYt1Y
# is_attack False
# is_policy False
# is_contrast False
#
# Governor Cuomo very likely broke state laws with this Moreland Scandal. Everyone in Albany knows it. https://t.co/s28qXS2keP #CuomoGate
# is_attack True
# is_policy False
# is_contrast False
#
# @KelticSC @fitsnews @nikkihaley @vincentsheheen maybe but I live in and love SC. Someone needs to save this state from the GOP establishment
# is_attack True
# is_policy False
# is_contrast False
#
# @ParableJean The challenge is solving problems w/out forced compliance. Good ideas shouldn't require coercion. @TedNugent
# is_attack False
# is_policy False
# is_contrast False
#
# Great to have the entire GOP ticket united for economic change! #ctgov http://t.co/RGqxNA0RJr
# is_attack False
# is_policy False
# is_contrast False
#
# WATCH: World famous TV host Hugh Downs is supporting Fred for governor http://t.co/KasCtycgPv #AZForward!
# is_attack False
# is_policy False
# is_contrast False
#
# Another group of amazing @iowademocrats here in Henry Co. #IowasFreshStart http://t.co/5ZV5GmgjNI
# is_attack False
# is_policy False
# is_contrast False
#
# (3/3) Nebraskans don't support taxpayer funds used to pay for abortions. RT if you agree. Story here: http://t.co/BqskovNpPO #prolife #negov
# is_attack False
# is_policy False
# is_contrast False
#
# Wake up, Alabama! Gov. Bentley can't see our pain, he's flying high on two state planes. https://t.co/LS5Ox1TdKI #Griffith4Gov
# is_attack True
# is_policy False
# is_contrast True
#
# Today is Joe Dorman's birthday!
# Retweet to wish Joe a happy birthday! http://t.co/WP1vFznFEo
# is_attack False
# is_policy False
# is_contrast False
#
# @theharryshearer RT! Want politics that puts people, peace &amp; planet b4 profit? #VoteGreen #NYGov Hawkins/Jones http://t.co/h5SkRFT1Pl
# is_attack False
# is_policy False
# is_contrast False
#
# Minnesota Receives Additional $5 Million in Federal Highway Funds Following Statewide Flooding http://t.co/GqdqAFUD7I #mnleg
# is_attack False
# is_policy False
# is_contrast False
#
# Packed house at #AAPI endorsement, thanks for hosting event that showed power of community engagement! #mapoli #magov http://t.co/EfVpExG9hO
# is_attack False
# is_policy False
# is_contrast False
#
# Live on http://t.co/sU0oqY3Hur: State leaders, Consul General @IdoAharoni brief media following #NYIsraelUnity trip http://t.co/DTuBk3TfvZ
# is_attack False
# is_policy False
# is_contrast False
#
# Heading into the polling place earlier this am w/ my friends @NicoleCollier95 @RoyCBrooks @MarcVeasey! #MyTexasVotes http://t.co/IgbPwRnUuO
# is_attack False
# is_policy False
# is_contrast False
#
# .@WolfForPA avoided paying his fair share of PA taxes, but wants to triple yours. Hypocrisy? https://t.co/D6JiE0kKeY
# is_attack False
# is_policy False
# is_contrast False
#
# Rick Scott and First Lady Ann Scott had the honor of meeting Florida vets tonight with @TheLeeGreenwood in Fort Myers http://t.co/dVVRNmMEXx
# is_attack False
# is_policy False
# is_contrast False
#
# Dan Malloy is the only candidate in this race that would never, ever repeal Connecticut’s smart gun safety laws. #ctprogress #ctgov
# is_attack False
# is_policy False
# is_contrast False
#
# Couldn't make the @FreeandEqual debate? No problem. Go here for a live feed: http://t.co/LR4cAR27RA
# is_attack False
# is_policy False
# is_contrast False
#
# Joan Rivers was an iconic New Yorker whose wit and humor will always be remembered. Statement: http://t.co/GwswlJoyon
# is_attack False
# is_policy False
# is_contrast False
#
# Help Colorado get a $10K grant! Vote for CO’s emergency flood response efforts in America's Transportation Awards. http://t.co/91vKJkhI1c
# is_attack False
# is_policy False
# is_contrast False
#
# We were very fortunate yesterday to have U.S. Senator Elizabeth Warren come to New Mexico and speak on behalf of... http://t.co/Efhqyggct6
# is_attack False
# is_policy False
# is_contrast False
#
# .@lopezcantera: Cuando Crist abandonó a la Florida Rick Scott le dio frente a los problemas y superó la crisis https://t.co/7Y8qzVzskP
# is_attack True
# is_policy False
# is_contrast False
#
# Our first TV ad shows who @GregAbbott_TX is really working for: his insider friends. See it here first: http://t.co/QyLaIBhlQ3
# is_attack True
# is_policy True
# is_contrast True
#
# "RI needs a jobs governor right now and I have the skills &amp; experience to be that jobs governor." #nbc10debate
# is_attack False
# is_policy False
# is_contrast False
#
# Hear what Manny Pacquiao has to say about Duke Aiona for Governor. https://t.co/BsX5SG9WBr... http://t.co/YdbTpSQ8zA
# is_attack False
# is_policy False
# is_contrast False
#
# Haven't voted yet? Make your voice heard next Tuesday. Make your plan to vote at http://t.co/tYNFCi981n. #MyTexasVotes
# is_attack False
# is_policy False
# is_contrast False
#
# Ricardo, that's amazing! MT @moonstar2186 Early voted with my entire Political Science Class in El Paso!!! #TeamWendy http://t.co/AV75Doi4gi
# is_attack False
# is_policy False
# is_contrast False
#
# Already voted for Wendy? Change your Twitter &amp; FB profile pictures to this &amp; show that #TeamWendy pride! -#TeamWendy http://t.co/ti0DS1FFu8
# is_attack False
# is_policy False
# is_contrast False
#
# .@WolfForPA calls for creation of charter schools office that already exists #pagov cc: @edmahonreporter http://t.co/yUilOqnkAl
# is_attack False
# is_policy False
# is_contrast False
#
# Terrific event this evening at the South Peninsula Area Republican Coalition Picnic. @ArLyneDiamond http://t.co/UjOWw1OUeO
# is_attack False
# is_policy False
# is_contrast False
#
# “This is not someone who knows what it’s like to fight to make ends meet.” —Julie Kushner, UAW Region 9 #FoleyFails http://t.co/gQWT9UaFDK
# is_attack False
# is_policy False
# is_contrast False
#
# Not a single question for @ltgovbrown on his failed health exchange? Wow.
# is_attack False
# is_policy False
# is_contrast False
#
# @AvgAndy Hi Andy- we apologize for the delay. We checked and your PCR should be in the mail. If not received by Tuesday please let us know.
# is_attack False
# is_policy False
# is_contrast False
#
# #tbt to 112 Cong, when Mike gave @BarackObama @newbalance shoes to make case for Berry Amdnt compliance #mepolitics http://t.co/PkndCGQmka
# is_attack False
# is_policy False
# is_contrast False
#
# @camcamsmom2010 Thanks for the follow. Any help you can give the #Wyllie4Gov campaign is appreciated.
# is_attack False
# is_policy False
# is_contrast False
#
# A Message from @WyllieForGov's Lt Gov Greg Roe "This Is It!" Get Out The Vote! https://t.co/QwPD0QXOJd #FLGov #FLElection #NextFLGov
# is_attack False
# is_policy False
# is_contrast False
#
# LETTER TO THE EDITOR: "What he has done means more than the TV ads” @DMRegister http://t.co/5saYdS7KDS
# is_attack False
# is_policy False
# is_contrast False
#
# Meeting amazing volunteers all over the state is what keeps me going. Thank you, Webster!  #TeamWendy http://t.co/jZXCXTP4hM
# is_attack False
# is_policy False
# is_contrast False
#
# Reverb stopped by to learn about my political views and how I can get the job done in Colorado. #RestoreLiberty2014
# - http://t.co/Y7YcK7rI2Q
# is_attack False
# is_policy False
# is_contrast False
#
# Speaking with members of Iron Workers Local 8 in Milwaukee for Labor Fest! http://t.co/Q25O0B0HYr
# is_attack False
# is_policy False
# is_contrast False
#
# Gov. Branstad speaks at the @iowadot US 34 bridge opening ceremony in Pacific Junction #iagov http://t.co/AqndSVMfYW
# is_attack False
# is_policy False
# is_contrast False
#
# Great tour of LCCC-exciting innovation taking place at our community colleges. Thanks LCCC students and staff. http://t.co/eMFD2BcXtX
# is_attack False
# is_policy False
# is_contrast False
#
# Honored to have the support of #Pinetop-Lakeside Mayor Roger Williams!  #azgov #BroadCoalition #Ducey2014 http://t.co/w4vxnpDi4E
# is_attack False
# is_policy False
# is_contrast False
#
# #HowieHawkins. The only candidate for Gov in NY that supports a #banfracking, 100% clean energy by 2030. http://t.co/cGmEJ4ldjO
# is_attack False
# is_policy False
# is_contrast False
#
# @kenwilley Many forget to mention: There is more party crossover than what a 3rd party draws from ea. @CindyGravesFL @MelissainJax
# is_attack False
# is_policy False
# is_contrast False
#
# I appreciate the Pheasant Habitat Work Group's efforts to develop solutions for maintaining pheasant habitat. http://t.co/DovluYCYk1
# is_attack False
# is_policy False
# is_contrast False
#
# Before you vote this Tues Nov04 - research the candidates, then vote FOR who you want. http://t.co/lwjxkdE8Lh #NextFLGov
# is_attack False
# is_policy False
# is_contrast False
#
# Geared up for tomorrow's #Husker game! RT if you are too! #GBR
# is_attack False
# is_policy False
# is_contrast False
#
# The moon over King's Beach in Lynn / Swampscott. Beautiful. http://t.co/ZWBEsEVFov
# is_attack False
# is_policy False
# is_contrast False
#
# TODAY is the deadline to register to vote and to change your information! http://t.co/ABrF8K8HMo #okgov http://t.co/36gT876lHg
# is_attack False
# is_policy False
# is_contrast False
#
# A must-read article!
#
# http://t.co/z9YZCGhhZL http://t.co/EnK6QTU5fT
# is_attack False
# is_policy False
# is_contrast False
#
# "@WolfForPA said Wednesday he will likely raise taxes on workers with income as low as $70,000" -@WashTimes #pagov http://t.co/ZNp0UjMjKb
# is_attack False
# is_policy False
# is_contrast False
#
# 34 City Tour - Hutchinson
# Grab some lunch and meet Keen @PizzaRanch in Hutch around 11:45 today. #ksgov
# is_attack False
# is_policy False
# is_contrast False
#
# The reviews are in on @GregAbbott_TX’s non-answer on the TEF scandal last night. http://t.co/11PKVgHylb #TexasDebates http://t.co/2tJV5PPLKn
# is_attack True
# is_policy False
# is_contrast False
#
# @mikeyjc97 Thanks for the follow &amp; RT's. Any help you can give the #Wyllie4Gov campaign is appreciated. Consider volunteering in Tampa?
# is_attack False
# is_policy False
# is_contrast False
#
# Who are we to tell people who to love or who to marry? Even the Pope said it - who are we to judge? #T51Debate
# is_attack False
# is_policy False
# is_contrast False
#
# There is a wild card in the #KSGov race: Libertarian candidate Keen Umbehr http://t.co/UKxn0ZUEVY #keenforkansas
# is_attack False
# is_policy False
# is_contrast False
#
# Dayton’s Incompetence Tour Hits Rochester. This latest debacle could have been avoided. http://t.co/xKBSwMvgym http://t.co/hrd8rhYjq7
# is_attack True
# is_policy False
# is_contrast False
#
# "A Superintendent Explains The Truth About Act 10 to Mary Burke"
# http://t.co/5NvDmT3hJn
# is_attack True
# is_policy False
# is_contrast False
#
# .@CharlieCrist admitted it. He was powerless to help the jobless. https://t.co/QZphTN6i2F #flgov #sayfie
# is_attack True
# is_policy False
# is_contrast False
#
# RT @BloombergTV: COMING UP: Watch Warren Buffett, Lloyd Blankfein, Michael Bloomberg, Rick Snyder live from Detroit http://t.co/Qp5YuiXC1E
# is_attack False
# is_policy False
# is_contrast False
#
# When I hear excuses, it tells me that the person doesn't really intend to work to fix the problem. - JC #GeorgiasReady #gapol
# is_attack False
# is_policy False
# is_contrast False
#
# Some important information about the parties. Anti-birth control, anti-women.
# http://t.co/qJ4FEHrtcT
# http://t.co/uNDoLIX1rc
# is_attack False
# is_policy False
# is_contrast False
#
# So happy to hear Malala won the Nobel Peace Prize!
# http://t.co/9VSlT8SdH9... http://t.co/TJbJv3jVt7
# is_attack False
# is_policy False
# is_contrast False
#
# State technology overhaul behind schedule; could affect single-payer launch - carnival of incompetence continues http://t.co/5iLsiET1F4
# is_attack False
# is_policy False
# is_contrast False
#
# Met w/ members of Hispanics Organizing for Public Education in Austin today. Thanks for fighting for our TX schools! http://t.co/uMNRZVbYjE
# is_attack False
# is_policy False
# is_contrast False
#
# Great time at the @UAPBAthletics Tailgate in #PineBluff! Good seeing everyone! #ARGov http://t.co/nAijkstUiY
# is_attack False
# is_policy False
# is_contrast False
#
# Sunday, I visited my 50th church of this campaign. I'm always inspired meeting people of faith across Texas. #MyTexas http://t.co/fZQe3CRVqM
# is_attack False
# is_policy False
# is_contrast False
#
# Rick Scott is a better governor. RETWEET to show your support! http://t.co/QdD9qq0Ao8 #letskeepworking #flgov #sayfie http://t.co/24aUE73voT
# is_attack False
# is_policy False
# is_contrast False
#
# Good luck today in Houston! RT @PamelaChomba: The Heights is ready to canvass! First some best practices. #TeamWendy http://t.co/oCuqTKBUol
# is_attack False
# is_policy False
# is_contrast False
#
# ICYMI: 6 things Michiganders are feeling instead of a recovery thanks to Gov. Snyder http://t.co/whkraXW8za http://t.co/T6ddcoHKsn
# is_attack True
# is_policy False
# is_contrast False
#
# Such a fun night of galas, dances and award ceremonies, So many great things happening in RI! http://t.co/52mTPRH18A
# is_attack False
# is_policy False
# is_contrast False
#
# We need to stop robbing Peter to pay Paul in our university system and come up with a equalization formula to fund our schools #UNIForum
# is_attack False
# is_policy False
# is_contrast False
#
# PRESS CLIPS: The Fresh Start RV made a stop in Knoxville yesterday. Check out some local coverage: http://t.co/98QPh6tQR1
# is_attack False
# is_policy False
# is_contrast False
#
# @MikeMyher Thanks for the follow. Any help you can give the #Wyllie4Gov campaign is appreciated. Consider volunteering for the campaign?
# is_attack False
# is_policy False
# is_contrast False
#
# Hillary Clinton: No place gets up off the mat like Michigan http://t.co/VyOWTutOKC http://t.co/BjhT2GexNW
# is_attack False
# is_policy False
# is_contrast False
#
# WATCH: Tuesday, November 4, 2014 is the day we can change our future and move #AZForward! http://t.co/SlzgdENm09 RT to help spread the word!
# is_attack False
# is_policy False
# is_contrast False
#
# THANK YOU VERY MUCH! THIS ENDORSEMENT MEANS WHOLE LOT MORE TO ME--BEING ENDORSED BY REFORM-MINDED PEOPLE AS... http://t.co/2C3qqEX5L3
# is_attack False
# is_policy False
# is_contrast False
#
# Places to find Pete this week:
# Today, 7-9 p.m. Gillette, WY  Nick Carter's Law Firm,  315 S. Gillette Avenue... http://t.co/a1WukkzOw4
# is_attack False
# is_policy False
# is_contrast False
#
# Thanks y'all! MT @BGTXSouthDallas #TeamDeSoto joint phonebank. @moonfattie @morning_whiskey #MyTexasVotes #TeamWendy http://t.co/v6YFTfLpkX
# is_attack False
# is_policy False
# is_contrast False
#
# @SpaceCoastLaw @alisonmf @whistleblow_now #WyllieForGov excluded but answered Livestream, watch recording http://t.co/lMbJAV4FoY
# is_attack False
# is_policy False
# is_contrast False
#
# CT’s investment in manufacturing is paying off as companies like TOMZ Corp. are expanding &amp; creating jobs:
# http://t.co/76H3zHiPNy #CTForward
# is_attack False
# is_policy False
# is_contrast False
#
# TOMORROW: Join @AppelforIowa and I at the @AU4Change bus tour stop in Des Moines. 1PM at the State Capitol
# is_attack False
# is_policy False
# is_contrast False
#
# Standing with @maura_healey to urge @MIAA033 to adopt stronger policies to stop teen dating violence http://t.co/hwwGjk0IFg #VAW #mapoli
# is_attack False
# is_policy False
# is_contrast False
#
# I am glad to have the endorsement of the @PioneerPress: http://t.co/JYe3DO23CH #mngov
# is_attack False
# is_policy False
# is_contrast False
#
# We’re establishing a low-interest loan fund to assist North Country businesses that are expanding and creating jobs: http://t.co/fz7K7wM42p
# is_attack False
# is_policy False
# is_contrast False
#
# .@WolfForPA says he's running one of the most transparent campaigns ever but calls details a distraction. #pagov https://t.co/NEZ2X9YXwQ
# is_attack False
# is_policy False
# is_contrast False
#
# https://t.co/cd15NjnXMx http://t.co/D7KPcCGPDD
# is_attack False
# is_policy False
# is_contrast False
#
# FACT: Crime is down to historic lows under Malloy-Wyman. http://t.co/Tgbyj0EHIe #ctgov #cdebate
# is_attack False
# is_policy False
# is_contrast False
#
# Thanks to everyone who came to the tour stop in Winter Park! #letskeepworking #flgov #sayfie http://t.co/37ueka2aUz
# is_attack False
# is_policy False
# is_contrast False
#
# @shiftySBS Need to start braking now - or, at least, start pulling on the steering wheel to run parallel w/ the cliff.
# is_attack False
# is_policy False
# is_contrast False
#
# Don't mess with Texas women. http://t.co/gHaV186w5d
# is_attack False
# is_policy False
# is_contrast False
#
# Have you seen our new ad featuring President @BillClinton? https://t.co/aNg3XPDhJz #ctprogress #ctgov
# is_attack False
# is_policy False
# is_contrast False
#
# Nancy Wyman and @jahimes helped us open our new HQ in Monroe! http://t.co/teTGOJR6KR
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you Emily! RT @_EmilyNorton Happy to canvass in the rain for Martha in #newtonma #mapoli  #teammartha http://t.co/Lekbti5UMN
# is_attack False
# is_policy False
# is_contrast False
#
# Libertarian gubernatorial candidate Wyllie says he's offering real solutions http://t.co/LhgSATR8sW via @MyNews13 #NextFLGov #FLGov
# is_attack False
# is_policy False
# is_contrast False
#
# Conservation &amp; cooperation is the new paradigm. Working together for solutions &amp; results is the #Colorado way. @COWaterCongress @COWaterPlan
# is_attack False
# is_policy False
# is_contrast False
#
# .@CharlieCrist’s attacks on Governor Scott are baseless and misleading http://t.co/HtELNYqulu #FLDebate
# is_attack True
# is_policy False
# is_contrast False
#
# Congratulations to the @PhoenixMercury for advancing to the WNBA Finals!
# is_attack False
# is_policy False
# is_contrast False
#
# Attempting to open eyes and minds. #invisiblecandidates #keenforkansas #ksgov
# is_attack False
# is_policy False
# is_contrast False
#
# http://t.co/cdgXS4wleZ
# is_attack False
# is_policy False
# is_contrast False
#
# Talking to voters at Dominica Manor about bringing manufacturing jobs back to our state: http://t.co/9Wu5ZyP2YW
# is_attack False
# is_policy False
# is_contrast False
#
# Some of you have asked about upcoming debates. Please see the following for more info: http://t.co/tPOEoKVQhX
# is_attack False
# is_policy False
# is_contrast False
#
# .@MIRSnews: Whitmer Challenges Baird To Sue Her http://t.co/Mxid8Tb0Zh
# is_attack False
# is_policy False
# is_contrast False
#
# .@SenBlumenthal: “We have done way better than New Jersey and the rest of New England on job creation." #ctprogress #ctgov
# is_attack False
# is_policy False
# is_contrast False
#
# A new @YouGov poll shows Pete with a 50 percent to 32 percent lead over his opponent. RT to share! Details: http://t.co/v9uNYGJMhb #negov
# is_attack True
# is_policy False
# is_contrast False
#
# At Floyd’s Family Restaurant in Manistique speaking with Michiganders. http://t.co/d0eH5e1J4H
# is_attack False
# is_policy False
# is_contrast False
#
# 7/16- Bentley considers hurting economy by raising taxes. #BentleysBadMonth #AmericasWorstGovernor http://t.co/yn6zqJQbnA
# is_attack True
# is_policy True
# is_contrast False
#
# Larry will join @derekahunter on @wbalradio today around 1:30! Tune in to AM 1090 or listen online at http://t.co/QbSy5qPchj #mdpolitics
# is_attack False
# is_policy False
# is_contrast False
#
# @them0thman Congrats! And Thanks for the support! Also, consider joining the http://t.co/OqmDRA41S7
# is_attack False
# is_policy False
# is_contrast False
#
# Make a plan to vote tomorrow. Find your polling place here: http://t.co/8RTtvQdbGB #ctgov #ctprogress http://t.co/qaPAgzEda0
# is_attack False
# is_policy False
# is_contrast False
#
# You know who we're with when eating ice cream at 9 AM-- Great to be joined by @SteveGrossmanMA at @CabotsIceCream! http://t.co/j8k3QW3hsS
# is_attack False
# is_policy False
# is_contrast False
#
# I have also proposed a new Open Doors for Students plan that will create accelerated BA programs and a new need-based loan program #UNIForum
# is_attack False
# is_policy False
# is_contrast False
#
# What county do you live in? You can search the voting locations by county on #MyTexasVotes: http://t.co/D5iLPRrlUe
# is_attack False
# is_policy False
# is_contrast False
#
# "I see a little theme here." Mayor -@marty_walsh introduces Dem nominees #Women2014 #mapoli http://t.co/ZtZ9vwa6SF
# is_attack False
# is_policy False
# is_contrast False
#
# If elected, @WolfForPA will block any effort to reform the state’s liquor monopoly. #pagov http://t.co/gJznybL3Xy #cbsphillydebate
# is_attack False
# is_policy False
# is_contrast False
#
# “I suppose I should point out @TomFoleyCT that to make the promises you’ve made you’ll have to balance it on people paying property taxes.”
# is_attack True
# is_policy True
# is_contrast False
#
# Spoke w/ employees at Packer City International Trucks in Brown Co.
# &amp; received the endorsement of small businesses in WI through NFIB.
# is_attack False
# is_policy False
# is_contrast False
#
# Want to get more involved? Keep up with #TeamSchauer on Facebook http://t.co/7hJCJmGmyp
# is_attack False
# is_policy False
# is_contrast False
#
# @ParisBienert Built the largest nonpartisan grassroots organization to spread awareness &amp; bring people together to fix our problems.
# is_attack False
# is_policy False
# is_contrast False
#
# Florida’s economy is back on track!  http://t.co/GQJoQuKoAg #letskeepworking #flgov #sayfie http://t.co/b1jKVUgiFE
# is_attack False
# is_policy False
# is_contrast False
#
# Because Rick Scott failed to expand health care, parents are struggling. Heartbreaking: http://t.co/ni8VSYiRtS http://t.co/sLloruEse4
# is_attack True
# is_policy True
# is_contrast False
#
# #lpac2014 Joel Salatin talking about "Effective Messaging for Food Freedom"
# is_attack False
# is_policy False
# is_contrast False
#
# Innovation paired with data can reduce healthcare disparities.... http://t.co/uSRHRLNP9S
# is_attack False
# is_policy False
# is_contrast False
#
# A great week so far for new job announcements. Headlines from all over! #OhioWorks http://t.co/rELVsUxbMp
# is_attack False
# is_policy False
# is_contrast False
#
# RI can become a national model for clean energy deployment and climate change preparedness: http://t.co/gqW4un3fs9
# is_attack False
# is_policy False
# is_contrast False
#
# Dan’s plan to grow CT’s economy — Expand Opportunities for Minority Contractors. #CTprogress http://t.co/8ZxsT7060g http://t.co/YHvrGq1ECO
# is_attack False
# is_policy False
# is_contrast False
#
# The Yes We Cannabis Forum will bring together a diverse &amp; creative group of panelists on Nov. 2nd. Tickets are FREE! http://t.co/ULn8wew1Ot
# is_attack False
# is_policy False
# is_contrast False
#
# Nan Rich said that if she loses the primary she’ll endorse Charlie Crist and join his campaign. If so, I hope... http://t.co/pkY3cBVMLW
# is_attack True
# is_policy False
# is_contrast False
#
# How bout those @Cowboys. Another win. #nfl
# is_attack False
# is_policy False
# is_contrast False
#
# Make sure to tune into Good Day New York on @MyFoxNY tomorrow at 7:30am! I'll be on with @rosannascotto and @gregkellyfox5!
# is_attack False
# is_policy False
# is_contrast False
#
# Ribbon cutting at Mid-State Truck Service in Lake Hallie: http://t.co/xzI7zvSmdQ
# is_attack False
# is_policy False
# is_contrast False
#
# Visited family-owned &amp; run McClay Cottonwood Dairy Farm and their approx 400 cows. That's a lot of #moo. #StateOfCO http://t.co/Cjm8OlVG68
# is_attack False
# is_policy False
# is_contrast False
#
# @KaceBomb Thanks for the follow. Any help you can give the #Wyllie4Gov campaign is appreciated. Consider volunteering in Tampa? #TakeAStand!
# is_attack False
# is_policy False
# is_contrast False
#
# East River State Park was badly in need of repairs after damage from #Sandy, but with this restoration we've built it back better than ever.
# is_attack False
# is_policy False
# is_contrast False
#
# Join Communities for Sheheen today: http://t.co/z5YD7NDyHC http://t.co/UYXKjQhIta
# is_attack False
# is_policy False
# is_contrast False
#
# Great news! MT @OhioBWC Ohio employers can expect rebate checks to be mailed next month. Keep an eye on your mailbox! #abillionback
# is_attack False
# is_policy False
# is_contrast False
#
# Hard to believe Manning broke Favre's TD record. Congrats! http://t.co/o9XhmaTuaM
# is_attack False
# is_policy False
# is_contrast False
#
# @jmar526 Thank you!
# is_attack False
# is_policy False
# is_contrast False
#
# Just early voted with my wife, Susan! There's still time for you to early vote, too: http://t.co/rg0ra5ZZLG #ARGov http://t.co/IpLMPxhqst
# is_attack False
# is_policy False
# is_contrast False
#
# @NightclubGenius @DearBubbie @TeddWebb1 Being fiscally conservative,we make our $$ go a long way,went all over FL raising more than we spent
# is_attack False
# is_policy False
# is_contrast False
#
# Primary Election Day is almost here! RT if you're ready for new leadership for NH!
# #nhpolitics #nhgov http://t.co/EyAB8ed1ha
# is_attack False
# is_policy False
# is_contrast False
#
# I will sit down and find consensus when I am elected Gov. #mddebate
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you! RT @bluebostonian Martha Coakley killed the #magovdebate tonight. I can't wait to cast my vote for her next Tuesday!
# is_attack False
# is_policy False
# is_contrast False
#
# Tonight John Hickenlooper stood in the West Slope and defended Washington, esp. re: federal gov't mgmt of our lands. I disagree governor.
# is_attack True
# is_policy False
# is_contrast True
#
# Tune into @1030_KVOI RIGHT NOW to catch me on @wakeupTucson. http://t.co/TnG64w76ls
# is_attack False
# is_policy False
# is_contrast False
#
# The support from our volunteers is incredible. Thank you all! #letskeepworking http://t.co/0lQaRMS2xC
# is_attack False
# is_policy False
# is_contrast False
#
# What winning looks like. #WinningOrLosing http://t.co/xXMSS41g8P
# is_attack False
# is_policy False
# is_contrast False
#
# Another child pornographer jailed this week. We'll keep at it until every last one is behind bars #txlege #tcot  http://t.co/yymgHaWRlq
# is_attack False
# is_policy False
# is_contrast False
#
# @KateeBurnss In @Gainesville this Sat Sep27 at a Meet&amp;Greet, come by / tell your friends @UF etc : http://t.co/KIUuvdGcSt #Wyllie4Gov
# is_attack False
# is_policy False
# is_contrast False
#
# John Hickenlooper has been to Colorado Springs "at least" 30 times. There you have it folks. #leadership #copolitics
# is_attack True
# is_policy False
# is_contrast False
#
# We need to be both tough on crime AND smart on crime to reduce incarceration rates and protect Oklahomans #okvotes14
# is_attack False
# is_policy False
# is_contrast False
#
# .@NYGovCuomo has time for a book tour, but he doesn’t have time to face the voters of New York. http://t.co/MCQquv1ifU
# is_attack True
# is_policy False
# is_contrast False
#
# Tmrw is the 20th anniversary of #VAWA, a landmark American achievement -- and a law that's saved countless lives.
# is_attack False
# is_policy False
# is_contrast False
#
# Rally with us this Tuesday:
#
# http://t.co/jQTqEfJVIw
# is_attack False
# is_policy False
# is_contrast False
#
# Today we reopened the improved East River State Park waterfront in Brooklyn: http://t.co/TWTRCYA0gp @NYstateparks http://t.co/4PLnI9r1sI
# is_attack False
# is_policy False
# is_contrast False
#
# @camchisel @billpostmus @foxandfriends thank you. God bless
# is_attack False
# is_policy False
# is_contrast False
#
# .@utbeth73 I will add 500 DPS officers, more Texas Rangers &amp; funding for local law enforcement, I'll enforce the rule of law.
# is_attack False
# is_policy False
# is_contrast False
#
# 50 days to go! We're fighting for the future of Florida. Are you in? http://t.co/VLjJp5utzO http://t.co/asJTNipt3Q
# is_attack False
# is_policy False
# is_contrast False
#
# ICYMI: "As someone who works to eradicate cycles of poverty &amp; violence...Martha has been a leader." -@AyannaPressley http://t.co/4ORF1kQT9Q
# is_attack False
# is_policy False
# is_contrast False
#
# Rick Scott's record on the environment is an absolute disaster. Via the @TB_Times: http://t.co/ltcSp7N1W2 http://t.co/NyGxq8mx7k
# is_attack True
# is_policy True
# is_contrast False
#
# .@JennaCTosh Thank you, Jenna! Great to have @FLWaW on #TeamCharlie.
# is_attack False
# is_policy False
# is_contrast False
#
# Ohio's tech industry is growing by leaps and bounds. Great news up in Cleveland: http://t.co/30jqt1E6Oq
# is_attack False
# is_policy False
# is_contrast False
#
# Today is the last day to vote early! Find your closest voting location: http://t.co/I2k9ZGYFzv  http://t.co/AxGYXV7Ngo
# is_attack False
# is_policy False
# is_contrast False
#
# Let's go, #JRW! Your state of Illinois is behind you all the way!
# is_attack False
# is_policy False
# is_contrast False
#
# Editorial from @toledonews: The Snyder scandals - http://t.co/0UE6zHTT1X http://t.co/7iZ2bvAAFV
# is_attack True
# is_policy False
# is_contrast False
#
# Why Floridians have such a tough time to understand what’s good for them, when the Finnish people do?... http://t.co/wfsgGBZfg9
# is_attack False
# is_policy False
# is_contrast False
#
# SCOTT VS CRIST CATFIGHT --PART 3.
#
# Tune into CNN Tuesday at 7pm to watch Scott and Crist make Florida the... http://t.co/xo7U6layXm
# is_attack True
# is_policy False
# is_contrast False
#
# Thank you to the Galveston County Coalition of Black Democrats for honoring me with the "Time For A Change" award! http://t.co/aJJpcX3a5p
# is_attack False
# is_policy False
# is_contrast False
#
# ICYMI — New ad takes @TomFoleyCT to task for promising the gun lobby he’d repeal CT’s gun safety law: https://t.co/ahZrZgYlKe #FoleyFails
# is_attack True
# is_policy True
# is_contrast False
#
# Citizens of #Florida are overburdened by taxation VOTE @WyllieForGov for relief! http://t.co/3F4rkWbE8Y @SunSentinel #ItsNotWorking @WIOD
# is_attack False
# is_policy False
# is_contrast False
#
# Schauer's campaign said Tuesday that Snyder isn't on the side of regular people http://t.co/8FmyWsB7RA
# is_attack True
# is_policy False
# is_contrast False
#
# On Friday, @MichelleObama will be joining us in Orlando: http://t.co/nAlqx5Xbsj -- and Miami: http://t.co/dx6qxZXKjZ http://t.co/zwiP1KhH3l
# is_attack False
# is_policy False
# is_contrast False
#
# .@WOODTV: Teachers protest pension tax at Snyder town hall - http://t.co/SUYfAUmxg6
# is_attack True
# is_policy True
# is_contrast False
#
# http://t.co/fQ3Gb9YWAj http://t.co/RRGSdlvhKT
# is_attack False
# is_policy False
# is_contrast False
#
# Toured New Tech Metals in New Franken and spoke with employees at this growing company in NE WI. http://t.co/arGYTeY3WC
# is_attack False
# is_policy False
# is_contrast False
#
# Fantastic event with the Wausau Women's Network this morning -- great discussion of education, equal pay, and jobs. Thanks all for coming!
# is_attack False
# is_policy False
# is_contrast False
#
# “@TomFoleyCT frequently makes up numbers. He’s invented his own Foley math at this point." #ctdebate #ctgov
# is_attack True
# is_policy False
# is_contrast False
#
# 60 years worth of youth football coaching experience between these two guys. Along w/a million great stories. http://t.co/t8jfh6YTiw
# is_attack False
# is_policy False
# is_contrast False
#
# Sat Oct18 Come out &amp; support the @LP_Florida  #yardsale &amp; see Adrian (not4sale) in #Lakeland
# http://t.co/edXlrD20Ia @theledger @LedgerBill
# is_attack False
# is_policy False
# is_contrast False
#
# The @WyllieForGov economic plan will bring real jobs, provide relief to small business, restore prosperity http://t.co/ttL49OEYVp #tlot
# is_attack False
# is_policy False
# is_contrast False
#
# 7/21- AL students rank 50th in math after years of cuts.Bentley opposed to education lottery #BentleysBadMonth #AmericasWorstGovernor
# is_attack False
# is_policy False
# is_contrast False
#
# Thanks to the supporters and volunteers representing Team Asa at the parade in Gravette! #ARGov http://t.co/M4MWOrGfsT
# is_attack False
# is_policy False
# is_contrast False
#
# "We have a constitutional mandate to make sure every child in Pennsylvania gets a great education." -TW #PAgov #cbsphillydebate #PAgovDebate
# is_attack False
# is_policy False
# is_contrast False
#
# I hope to see you at the #mnstatefair. Get directions to our booth or sign up to work a shift. See you there! http://t.co/wzGV3rH2fJ
# is_attack False
# is_policy False
# is_contrast False
#
# @GailWhitney29 https://t.co/D4SOVBhd6k
# is_attack False
# is_policy False
# is_contrast False
#
# The governor we need for medical marijuana in Florida is Farid Khavari.
# He’s the one who will keep big business... http://t.co/S2TyKUeg8F
# is_attack False
# is_policy False
# is_contrast False
#
# Tons of blue! Great #TeamMalloy turnout! RT @CunningSylv: Scene outside #MalloyFoleyDebate at #UConn http://t.co/GucTjueID6
# is_attack False
# is_policy False
# is_contrast False
#
# Want to know more about @WyllieForGov? Watch his videos at http://t.co/DRtG6yZLHB #nextflgov #RickScott #CharlieCrist #flgov #liberty #tcot
# is_attack False
# is_policy False
# is_contrast False
#
# She did it! SO proud of my wife @Maine_AnnLePage. #veterans #freedomfest #mepolitics http://t.co/UhXsMrrpxd
# is_attack False
# is_policy False
# is_contrast False
#
# Todavía hay trabajo por hacer! #SigamosTrabajando con Rick Scott! http://t.co/7plNBHoaBc
# is_attack False
# is_policy False
# is_contrast False
#
# Just voted at Nathan Bishop Middle School! Look up your polling place here: http://t.co/vuGikTSd7v http://t.co/uM9oPYshOt
# is_attack False
# is_policy False
# is_contrast False
#
# Tell Joe Dorman &amp; his liberal groups that OK stands w/Mary as she opposes their efforts to bring Obamacare to OK! http://t.co/FThlWggE3x
# is_attack True
# is_policy True
# is_contrast False
#
# "One party rule over the last 2 years has not been a good thing for MN. Taxes were raised on all MNs" #FOX9Debate
# is_attack False
# is_policy False
# is_contrast False
#
# We have long advocated for equal rights for all Coloradans and today we find ourselves on the right side of history. #marriageequality
# is_attack False
# is_policy False
# is_contrast False
#
# Kids who have access to early childhood education hear "3 million more words" -@billclinton #EarlyEd matters. http://t.co/BMDp7CoZf5 #mapoli
# is_attack False
# is_policy False
# is_contrast False
#
# It looks like we have a debate!
#
# http://t.co/4HJ2OsmG9Y
# is_attack False
# is_policy False
# is_contrast False
#
# Reminder that @TomFoleyCT thought spending tonight w/ the Tea Party was more important than speaking to the voters. #ctgov #ctdebate
# is_attack True
# is_policy False
# is_contrast False
#
# Speaking at the Concerned Citizens of Saginaw community meeting about moving Michigan forward. #TeamSchauer http://t.co/yIRpJk817D
# is_attack False
# is_policy False
# is_contrast False
#
# Hassebrook: under current statute the gov has the authority to take away every day of good time...the current governor hasn't done it I will
# is_attack False
# is_policy False
# is_contrast False
#
# At last night's Dispensaries for Dunafon event, we solidified the fact that the relation... http://t.co/yYkC7x8g3g http://t.co/RwGyHFxKYe
# is_attack False
# is_policy False
# is_contrast False
#
# ...
# is_attack False
# is_policy False
# is_contrast False
#
# Government should strive to be as efficient w/taxpayer dollars as possible. We're helping make it happen. #OhioWorks http://t.co/wGaFn0Y3lz
# is_attack False
# is_policy False
# is_contrast False
#
# Put your absentee ballot in the mail today. Make your vote count! http://t.co/pn4WiS17ZV http://t.co/EAXA8QJc7C
# is_attack False
# is_policy False
# is_contrast False
#
# "We made a series of recommendations around domestic violence reform after the Remy case" https://t.co/vhj4dLE4c7 #MAGov14 #mapoli
# is_attack False
# is_policy False
# is_contrast False
#
# Another great FB live q&amp;a wrapped up on Pete Gosar for Governor. I look forward to Wednesdays more and more each week! #Connect
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you Media Revolt for their endorsement http://t.co/oEfc1tY6s1 #sayfie @SSNAlerts #tcot #tlot #nextflgov #Elections2014 #flgov #fangate
# is_attack False
# is_policy False
# is_contrast False
#
# Less than a week left for early vote–the time to volunteer is NOW: http://t.co/wvJiSkxWaY #MyTexasVotes
# is_attack False
# is_policy False
# is_contrast False
#
# Starting the day off right with a big breakfast at Louie M's in south O! -CH #negov
# is_attack False
# is_policy False
# is_contrast False
#
# 2. Make a plan today to vote in person on September 9th. Find your polling place: http://t.co/esBTBMA6Hh
# is_attack False
# is_policy False
# is_contrast False
#
# "We need a governor we can trust. We need a governor who supports public education…I ask for your vote" #scgovdebate
# is_attack False
# is_policy False
# is_contrast False
#
# #TeamMartha: ready to knock #demdoors this weekend? Hear why the work you do is so important: http://t.co/cFPqFFjt50 #org2win #mapoli
# is_attack False
# is_policy False
# is_contrast False
#
# Doing push-ups for the lead. Go Pokes! http://t.co/7WToO37qz7
# is_attack False
# is_policy False
# is_contrast False
#
# Many to thanks to our volunteers out at War Memorial for the Salt Bowl! Couldn't do it without you! #ARGov http://t.co/MmEgttR0y6
# is_attack False
# is_policy False
# is_contrast False
#
# Wondering why @hickforco can't give marijuana users get "cheers"? Perhaps because they don't make him rich. #dunafonforgov #copolitics
# is_attack False
# is_policy False
# is_contrast False
#
# Real solutions for the people of Hawai'i. #dukeiaona2014 #elwinahu #hitrust #hirespect #hibalance #higov... http://t.co/fXPyMHshDX
# is_attack False
# is_policy False
# is_contrast False
#
# Only 50 days left until election day! RETWEET if you will be voting Asa Hutchinson for Governor in 50 days! http://t.co/dUHVKAOqnj
# is_attack False
# is_policy False
# is_contrast False
#
# Firing up hard-working Michiganders to help us win in November. You can help here: http://t.co/m2mFlGi5FL http://t.co/MFJxXZMsSX
# is_attack False
# is_policy False
# is_contrast False
#
# Please come out and join me for a night of local hip-hop music at the Gothic this evening from 7-10pm! #Dunafon4Gov
# is_attack False
# is_policy False
# is_contrast False
#
# .@RalphNader to support @HowieHawkins Sept 14th in Albany! Consumer advocates #unite! Reserve your spot: http://t.co/XtogEHaL1M
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you to @9NEWS, CSU and the @Coloradoan for hosting tonight's debate. Working together, we can build a stronger Colorado. #fcdebate
# is_attack False
# is_policy False
# is_contrast False
#
# Joining @LarryOConnor and @BrianWilsonDC on @WMALMornings at the Silver Diner! #mdpolitics #changeMD http://t.co/JHxo2EHlYd
# is_attack False
# is_policy False
# is_contrast False
#
# @ChopLivah Thanks for the follow. Any help you can give the #Wyllie4Gov campaign is appreciated. Consider volunteering for the campaign?
# is_attack False
# is_policy False
# is_contrast False
#
# Enjoyed speaking with AdvancED this morning &amp; sharing my plans for education in Arkansas! #ARGov #ARPX http://t.co/qGl65XeIJC
# is_attack False
# is_policy False
# is_contrast False
#
# Happy Birthday, @HillaryClinton! Thanks for all your service &amp; for coming to #Philly to help give PA a fresh start: http://t.co/BxfPs9bMbH
# is_attack False
# is_policy False
# is_contrast False
#
# @JoshFalzone thanks for your support Josh!
# is_attack False
# is_policy False
# is_contrast False
#
# Read more about Joe Dorman's plan to provide students the opportunities to foster the active citizens Oklahoma needs: http://t.co/RlKxHMcKDn
# is_attack False
# is_policy False
# is_contrast False
#
# @journalsentinel I have been saying this for months. Reporters should ask for my perspective on things more often.  http://t.co/d4drfwcHkY
# is_attack False
# is_policy False
# is_contrast False
#
# John Hickenlooper supported the "trial lawyer full employment bill." I will not. #copolitics
# is_attack True
# is_policy False
# is_contrast False
#
# Tonight 4pm @WyllieForGov will be at the Candidate Forum in Belle Glade http://t.co/Ld6d0ZErr8  @SunSentinel @CBS12 @wsvn @nbc6 @WPLGLocal10
# is_attack False
# is_policy False
# is_contrast False
#
# Early voting begins today! Do you know where you vote? Look it up here: http://t.co/gwE6zVZjAT http://t.co/ODPGsVsfTU
# is_attack False
# is_policy False
# is_contrast False
#
# Wendy Davis supports full-day pre-K. Abbott's plan allows standardized tests on 4-year-olds to decide which kids get pre-K. #TexasDebates
# is_attack False
# is_policy False
# is_contrast False
#
# @jmannysmash Thanks for the follow. Any help you can give the #Wyllie4Gov campaign is appreciated.
# is_attack False
# is_policy False
# is_contrast False
#
# Vamos! RT @Annette_Taddeo: Hoy es la fecha límite. ¡Inscríbete para votar ya! http://t.co/WiByAQMlU0 #VotoLatino http://t.co/G3DCrE0pHM
# is_attack False
# is_policy False
# is_contrast False
#
# “Graduation rates are up!” #ctdebate
# is_attack False
# is_policy False
# is_contrast False
#
# "I want state government to work..for people who pay the bills, and for people who depend on the services the Commonwealth provides" #mapoli
# is_attack False
# is_policy False
# is_contrast False
#
# Who Is Captain of the Ship? http://t.co/pjJLyLn9Ej
# is_attack False
# is_policy False
# is_contrast False
#
# By saying goodbye to Charlie Crist and Rick Scott, you say goodbye to your suffering and economic hardship!
# is_attack True
# is_policy True
# is_contrast False
#
# Thank you to @okeducation, a longtime educator, for their latest, in depth blog, "Why I'm voting for Joe Dorman." http://t.co/uBUir2Sb9C
# is_attack False
# is_policy False
# is_contrast False
#
# “As governor, I will fight for your inalienable right to possess the tools to defend your life, liberty and property” http://t.co/CxSFnlx0ko
# is_attack False
# is_policy False
# is_contrast False
#
# We're comin' for you, New England! #Broncos #beatthepatriots http://t.co/BbFGihALck
# is_attack False
# is_policy False
# is_contrast False
#
# October is Idaho Domestic Violence Awareness Month. Let’s put an end to violent or abusive relationships. http://t.co/QPnmBZeCpJ
# is_attack False
# is_policy False
# is_contrast False
#
# .@NYDFS staff will be in Brookhaven tomorrow &amp; Babylon this weekend to provide insurance help after LI flooding: http://t.co/VhDzzmvmG9
# is_attack False
# is_policy False
# is_contrast False
#
# @Rach_IC @BradHubert @brianjsymes There are only 'libertarians'--no such thing as a conservative, liberal or moderate. 'Leaners' R liars.
# is_attack False
# is_policy False
# is_contrast False
#
# Ann and I are incredibly honored to receive a piece of steel from the World Trade Center. #mepolitics http://t.co/NAywEdEyMP
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you for voting by mail! RT @kaityballgame: Got my absentee and ready to vote for @CharlieCrist and make this a @ScottFreeFLA!
# is_attack False
# is_policy False
# is_contrast False
#
# .@WolfForPA is for higher taxes &amp; less jobs. @CorbettforGov is for lower taxes &amp; a growing economy. #pagov http://t.co/KF3KN8PsbV
# is_attack False
# is_policy False
# is_contrast False
#
# Have you seen the latest poll? The momentum is on our side &amp; this race is going to come down to turnout.
# http://t.co/1iBlvn9m5r #mngov
# is_attack False
# is_policy False
# is_contrast False
#
# YARD SIGNS ARE IN!  We have lots and lots of them, and we want to see them all over New Mexico in real voters... http://t.co/f2UBEPhgDK
# is_attack False
# is_policy False
# is_contrast False
#
# Thank you Kitty! MT @KittyKaufman I contributed to Martha's campaign #mapoli #teammartha. You can too. please go to: https://t.co/VAPNqfdexF
# is_attack False
# is_policy False
# is_contrast False
#
# .@MyTexasVotes is live and ready to answer your voting questions. Just tweet at us any time! #MyTexasVotes –Team Wendy
# is_attack False
# is_policy False
# is_contrast False
#
# The Legislature has already given the Gov the authority to take away good time. The current governor hasn't done it. I will #MOPOA  #NEGov
# is_attack False
# is_policy False
# is_contrast False
#
# Suzanne McDuell is our fan of the week! Thanks for the support Suzanne! http://t.co/QBWY6kBbwC
# is_attack False
# is_policy False
# is_contrast False
#
# .@freep FACT CHECK: This is true. Snyder's 2012 budget did cut higher education funding by 15% - http://t.co/EdNWvBHKlu #midebate
# is_attack False
# is_policy False
# is_contrast False
#
# #Cuomo needs to give out less corporate welfare and spend more money to provide education in prisons...@jimenezforag
# is_attack False
# is_policy False
# is_contrast False
#
# Speaking at Hispanic -  Latino Caucus. Sí Se Puede #TeamMDP
# is_attack False
# is_policy False
# is_contrast False
#
# If @TomFoleyCT wins, he’ll shut down schools like he’s closed factories and mills… #FoleyFails http://t.co/xhmQtw6jBk
# is_attack True
# is_policy True
# is_contrast False
#
# To debate or not? State GOP slow to share stage with Democrats - http://t.co/LP7FKUIyI0 http://t.co/jgKtbGygx7
# is_attack False
# is_policy False
# is_contrast False
#
# Almost at the @IowaStateFair to walk through the site for the @IowaPress @IowaPublicTV debate! #Hatchtag #IowaStateFair
# is_attack False
# is_policy False
# is_contrast False
#
# FIND OUT WHY FARID KHAVARI SHOULD BE ELECTED AS THE NEXT FLORIDA GOVERNOR—THE ECONOMIST WE NEED NOW!... http://t.co/iNcvhw5T1Z
# is_attack False
# is_policy False
# is_contrast False
#
# .@FEMA approves $47.8M in funding to make 20 bridges across NYS more resilient in the face of severe weather: http://t.co/6NtP2Pewmy
# is_attack False
# is_policy False
# is_contrast False
#
# A message from the #Wyllie4Gov campaign team: https://t.co/lhLkf9Kb11 Home from the #CraftBrew Tour of Fla @KevinDerbySSN #sayfie
# is_attack False
# is_policy False
# is_contrast False
#
# Celebrated Diwali w the India Association of RI tonight! Your community makes RI stronger! http://t.co/dkaEEoy8fJ
# is_attack False
# is_policy False
# is_contrast False
#
# Do you want to vote early? Click here to find out where to cast your ballot: http://t.co/c9rS6BHpfA #flgov #sayfie
# is_attack False
# is_policy False
# is_contrast False
#
# How incredible are our volunteers? Thank you for all your hard work and dedication! https://t.co/EEwyaKgaLw #letskeepworking
# is_attack False
# is_policy False
# is_contrast False
#
# Did you know that you can early vote in any location in your county? Find out more at http://t.co/tYNFCi981n #MyTexasVotes
# is_attack False
# is_policy False
# is_contrast False
#
# Everybody should know that all conventional economic concepts are obsolete and no longer useful! Economics must be reinvented!
# is_attack False
# is_policy False
# is_contrast False
#
# Happy #ConstitutionDay! The U.S. Constitution was signed on September 17, 1787. #thisdayinhistory http://t.co/QT6W0PwvjN
# is_attack False
# is_policy False
# is_contrast False
#
# Let’s keep working to protect Florida’s natural treasures. http://t.co/Z8i4SOA26k #letskeepworking #flgov #sayfie http://t.co/qkJtxEKloH
# is_attack False
# is_policy False
# is_contrast False
#
# @jpe33180 That's a good point. &amp; Would rather be an honest citizen than a career politician needing million$ to craft a faux image.
# is_attack False
# is_policy False
# is_contrast False
#
# FACT: Jason fought Gov. Deal's cuts to HOPE &amp; is the only candidate fighting to expand HOPE. https://t.co/aYdJk1YAgX RT to spread the FACTS.
# is_attack False
# is_policy False
# is_contrast False
#
# #fieldwins! MT @penlovespaper: Well, @CharlieCrist vols are certainly eager. two calls already tonight to remind me to vote. #promiseIwill
# is_attack False
# is_policy False
# is_contrast False
#
# @johnhrabe love it. Great idea!
# is_attack False
# is_policy False
# is_contrast False
#
# @teachsimon Not a complete privatization. But competition is good.
# is_attack False
# is_policy False
# is_contrast False
#
# My Friends,
# Last night in Aurora, while the Hickenlooper campaign was drinking beer and ... http://t.co/yYkC7x8g3g http://t.co/e1FumRLv0B
# is_attack True
# is_policy False
# is_contrast True
#
# “@PolitiFactWisc: What you might hear at Friday's Scott Walker-Mary Burke debate" Where's the other Burke?
# is_attack True
# is_policy False
# is_contrast False
#
# Thanks @WIOD, for giving the @WyllieForGov the opportunity to address voters in South Fla! Really went well! @JimmyCefalo @WIODManny
# is_attack False
# is_policy False
# is_contrast False
#
# @canosa I'm very much looking forward to this event, thank you for making it happen!
# is_attack False
# is_policy False
# is_contrast False
#
# I was honored to join the Fairpoint picket lines yesterday. I'm proud to stand for #FairnessAtFairpoint #mepolitics http://t.co/Ue1PfnyVIA
# is_attack False
# is_policy False
# is_contrast False
#
# Sat Aug30 #Wyllie4Gov #CraftBrew Tour heads to Ft Walton Beach @PropsBrewery http://t.co/xFKrPdQAXj @nwfdailynews @weartv @NFLibertarians
# is_attack False
# is_policy False
# is_contrast False
#
# @izzaboo Statute requires no more than 7 from one party. Gov. Mead needs to comply and many are watching disregard for law. #LawApplies2Gov
# is_attack True
# is_policy False
# is_contrast False
#
# If you experience any problems trying to vote, call our Voter Protection Hotline at 1-844-285-7711. RT to spread the word. #GeorgiasReady
# is_attack False
# is_policy False
# is_contrast False
#
# In #Alaska we have a fully functioning state legislative and executive branch working hard for the people. http://t.co/hrAOetnm2k
# is_attack False
# is_policy False
# is_contrast False
#
# https://t.co/WkZWfzeuH4 I will be answering all #FLGovDebate questions via livestream 2nd viewing option: http://t.co/qjzmJy81D6 #NextFLGov
# is_attack False
# is_policy False
# is_contrast False
#
# Hassebrook: as far as community college, I would make the state a partner with community colleges and high schools #netdebate
# is_attack False
# is_policy False
# is_contrast False
#
# Show us your creative signs! MT @JenDeJournett: Saw this on @Jeff4Gov sign ... It did make me ;) #theNameYouKnow http://t.co/yNSKi5qNbk
# is_attack False
# is_policy False
# is_contrast False
#
# "If we all work together... And we just vote. I know we can elect Martha Coakley." -@MichelleObama #FLOTUSMA #mapoli http://t.co/0wKKR53pGh
# is_attack False
# is_policy False
# is_contrast False
#
# Vice President Joe Biden Says Workers Deserve "Fair Share" - http://t.co/1jCjZAlDcC
# is_attack False
# is_policy False
# is_contrast False
#
# Can't find your polling place? Tweet @MyTexasVotes and we can find your nearest one! #MyTexasVotes –Team Wendy
# is_attack False
# is_policy False
# is_contrast False
#
# Want to catch up on #T51Debate? @nbc6 has put it up in English here: http://t.co/iXdtdrcCa0 - see what you missed!
# is_attack False
# is_policy False
# is_contrast False
#
# "Gun safety is not something that Connecticut citizens can take for granted.” http://t.co/o9cHHbyq70 #CTProgress #ctgov
# is_attack False
# is_policy False
# is_contrast False
#
# Basset hound gets bogus diploma from online academy. We shut this down. http://t.co/GD9boWq5DE
# is_attack False
# is_policy False
# is_contrast False
#
# RT @jacobkornbluh: @NYGovCuomo praying at the Western Wall http://t.co/f8qAKgsmTi #NYIsraelUnity
# is_attack False
# is_policy False
# is_contrast False
#
# Our campaign was excited to participate this weekend in Fiestas de las Americas! Great to be in parade &amp; festivities! http://t.co/BAcKXRISze
# is_attack False
# is_policy False
# is_contrast False
#
# .@statesman: Wendy can "pull together moderate Republicans and Democrats to forge what state legislators like to call Texas solutions." -TW
# is_attack False
# is_policy False
# is_contrast False

# %%
validation_file = "sample_validation_init.csv"
with open(validation_file, 'w') as f:
    f.write("{}, {}, {}, {}\n".format("text", "is_attack", "is_policy", "is_contrast"))
    for sample in list(random_total_sample) + list(random_attack_sample):
        text = sample["text"]
        text = text.replace(',', ';')
        is_attack = sample["is_attack"]
        is_policy = sample["is_policy"]
        is_contrast = sample["is_contrast"]
        f.write("\"{}\", {}, {}, {}\n".format(text, is_attack, is_policy, is_contrast))
